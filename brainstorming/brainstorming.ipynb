# %% [markdown]
# Let's brainstorm some ideas here.

# %% [markdown]
# World bank datasets:
#
# https://databank.worldbank.org/reports.aspx?source=2&series=NY.GDP.MKTP.CD&country=

# %%
import pandas as pd

wbFilePath = '../WorldBankData/Data_Extract_From_World_Development_Indicators/f44b1823-efd6-454c-a794-e1b62c508d58_Data.csv'
wbData = pd.read_csv(wbFilePath)
wbData.head()
# Out:
#          Series Name     Series Code    Country Name Country Code  \
# 0  GDP (current US$)  NY.GDP.MKTP.CD     Afghanistan          AFG
# 1  GDP (current US$)  NY.GDP.MKTP.CD         Albania          ALB
# 2  GDP (current US$)  NY.GDP.MKTP.CD         Algeria          DZA
# 3  GDP (current US$)  NY.GDP.MKTP.CD  American Samoa          ASM
# 4  GDP (current US$)  NY.GDP.MKTP.CD         Andorra          AND
#
#       2000 [YR2000]     2001 [YR2001]     2002 [YR2002]     2003 [YR2003]  \
# 0                ..                ..  4055176933.36905  4515563413.82564
# 1  3480355188.60063  3922099470.97313  4348070165.19261  5611492282.86582
# 2  54790245600.5846  54744714396.1666  56760288973.6703  67863829880.4832
# 3                ..                ..         514000000         527000000
# 4  1434429703.33518  1496912751.67785  1733116883.11688  2398645598.19413
#
#       2004 [YR2004]     2005 [YR2005]        ...            2009 [YR2009]  \
# ...

# %%
indiaData = wbData[wbData['Country Name'].str.contains('India', na=False)]
indiaData.head()
indiaData = indiaData.transpose()
indcol = indiaData.iloc[0]
indiaData.columns = indcol
indiaData = indiaData.rename_axis("Year", axis="columns")
indiaData = indiaData.loc['2000 [YR2000]':]
indiaData.head()
# Out:
# Year          GDP (current US$) GNI (current US$)  \
# 2000 [YR2000]  468394948471.616   463418971411.06
# 2001 [YR2001]  485441026156.549  481233333719.828
# 2002 [YR2002]  514937961192.908  511490048636.432
# 2003 [YR2003]   607699299977.15  603192907506.664
# 2004 [YR2004]  709148531774.823  704168762435.513
#
# Year          Unemployment, total (% of total labor force) (national estimate)  \
# 2000 [YR2000]                                   2.73060011863709
# 2001 [YR2001]                                                 ..
# 2002 [YR2002]                                                 ..
# 2003 [YR2003]                                                 ..
# 2004 [YR2004]                                                 ..
#
# Year          Inflation, consumer prices (annual %)
# 2000 [YR2000]                      4.00943591045191
# 2001 [YR2001]                      3.77929312235636
# 2002 [YR2002]                      4.29715203929568
# ...

# %% [markdown]
# Screw world bank data.
#
# Sample data from NOAA GFS dataset for each season for the past 10 years.
